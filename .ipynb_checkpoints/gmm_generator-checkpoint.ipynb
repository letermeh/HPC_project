# %%
import numpy as np
from scipy.stats import wishart

# %%
A = np.eye(3)
rv = wishart.rvs(11, A, size=10)

# %%
print(rv)
# Out:
# [[[22.04449917  4.39618605 -4.85197092]
#   [ 4.39618605 14.68825187 -6.35902495]
#   [-4.85197092 -6.35902495 14.27854807]]
#
#  [[ 7.03348618 -5.29187273 -3.12025518]
#   [-5.29187273 19.83727233  3.92537327]
#   [-3.12025518  3.92537327  4.23190089]]
#
#  [[ 9.10815235  0.56564829  3.44402065]
#   [ 0.56564829 17.52181487 -0.87680781]
#   [ 3.44402065 -0.87680781  9.59911405]]
#
#  [[ 9.24748183  1.78830913  0.32863278]
#   [ 1.78830913 21.71829383 -1.71855275]
#   [ 0.32863278 -1.71855275  8.39872373]]
#
#  [[ 8.01863025  1.06615678  1.43166468]
#   [ 1.06615678  8.26145574  2.26906426]
#   [ 1.43166468  2.26906426 11.09171645]]
#
#  [[10.69655526  3.67339694  2.73198399]
#   [ 3.67339694 10.3458193  -2.25108264]
#   [ 2.73198399 -2.25108264 11.63846392]]
#
#  [[23.60879123 -6.87149232 -3.06468192]
#   [-6.87149232  9.01562086 -2.128374  ]
#   [-3.06468192 -2.128374    8.53535191]]
#
#  [[21.23864801  0.66383015 -3.24914315]
#   [ 0.66383015  9.08596918  5.61992007]
# ...

# %%
def test(a, b=1, **kwargs):
    if 'c' not in kwargs.keys():
        kwargs['c']=0
    return a + b + kwargs['c']
